# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
img= cv2.imread("/users/iamns45/Desktop/CV/CV-3/Que-6/image1.jpg", 0)
img2= cv2.imread("/users/iamns45/Desktop/CV/CV-3/Que-6/image3.jpg", 0)
plt.figure(figsize = (20,2))
plt.imshow(img,cmap='gray', vmin=0, vmax=255)
plt.show()
plt.figure(figsize = (20,2))
plt.imshow(img2,cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
D=720 
T=20
b=546.1 
f=1203.54736624058 
z=(b*f)/(D-T) 
print('The Disparity based depth estimation is '+str(z)+'mm')
# Out:
# The Disparity based depth estimation is 938.9388810056869mm
